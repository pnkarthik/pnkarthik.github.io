# %% [markdown]
# ## Checking type

# %%
type("Hello World")

# %%
phrase = "Hello World"
type(phrase)

# %% [markdown]
# ## Delimiters -- single quotes and double quotes

# %%
string1 = 'Hello, world'
string2 = "1234"

# %% [markdown]
# ## Use of two delimiters

# %%
string3 = "We're in LH-06!"
string4 = 'I requested acads, "Please allot a bigger classroom."'

# %%
text = "She said, "
text1 = "What time is it?"

# %% [markdown]
# ## Length of a string

# %%
len("abc")
letters = "abc"
num_letters = len(letters)

print(num_letters)

# %%
type(len("abc"))

# %% [markdown]
# ## Multiline strings

# %%
paragraph = "The programming language Python was conceived in the late 1980s and its implementation was started in December 1989 by Guido van Rossum at CWI in the Netherlands as a successor to ABC capable of exception handling and interfacing with the Amoeba operating system. Van Rossum is Python's principal author, and his continuing central role in deciding the direction of Python is reflected in the title given to him by the Python community, Benevolent Dictator for Life (BDFL). (However, Van Rossum stepped down as leader on July 12, 2018.). Python was named after the BBC TV show Monty Python's Flying Circus. -- Credits: Wiki"

print(paragraph)

# %%
long_string = "This multiline is \
displayed on a single line"

print(long_string)

# %%
paragraph = "The programming language Python was conceived in the late 1980s \
and its implementation was started in December 1989 by Guido van Rossum at CWI \
in the Netherlands as a successor to ABC capable of exception handling and interfacing \
with the Amoeba operating system. Van Rossum is Python's principal author, and his continuing \
central role in deciding the direction of Python is reflected in the title given to him by the Python community, Benevolent Dictator for Life (BDFL) \
(However, Van Rossum stepped down as leader on July 12, 2018.). Python was named after the BBC TV show Monty Python's Flying Circus. -- Credits: Wiki"

print(paragraph)

# %%
print('''An example of a
   string that spans across multiple lines
      that also preserves whitespace.''')

# %%
paragraph = '''
The programming language Python was conceived in the late 1980s
and its implementation was started in December 1989 by Guido van Rossum at CWI
in the Netherlands as a successor to ABC capable of exception handling and interfacing
with the Amoeba operating system. Van Rossum is Python's principal author, and his continuing
central role in deciding the direction of Python is reflected in the title given to him by the Python community, Benevolent Dictator for Life (BDFL).
(However, Van Rossum stepped down as leader on July 12, 2018.). Python was named after the BBC TV show Monty Python's Flying Circus. -- Credits: Wiki '''

print(paragraph)

# %% [markdown]
# ## Concatenation, Indexing, and Slicing

# %%
string1 = "AI"
string2 = "1104"
concatenated_string = string1 + string2
concatenated_string

# %%
# By default, no whitespace is inserted when concatenating two strings. Whitespace, if needed, must be explicitly inserted.
first_name = "Karthik"
last_name_1 = "P."
last_name_2 = "N."
full_name = first_name + " " + last_name_1 + " " + last_name_2
full_name

# %%
course_name = "Programming for AI"
course_name[1]

# %%
course_name[0]

# %%
course_name[100]

# %%
course_name[-1]

# %%
course_name[-20]

# %%
last_character = course_name[-1]  # -1 is useful for getting the last index of a string.

# %%
first_three_letters = course_name[0] + course_name[1] + course_name[2]
first_three_letters

# %%
first_three_letters = course_name[0:3]
first_three_letters

# %%
course_name[0:100]

# %%
course_name[4:]

# %%
course_name[:8]

# %%
course_name[:]

# %%
course_name[-9:-6]

# %%
course_name[-100:]

# %%
course_name[:0]

# %% [markdown]
# ## Strings are Immutable

# %%
word = "goal"
# word[0] = "f"  # this is not the way to do
word_1 = "f" + word[1:]

print(word)
print(word_1)

# %%
word = "goal"

print(word[0:1])

print(word)

# %% [markdown]
# ## String Manipulations - Upper and Lower Case

# %%
my_name = "Karthik P. N."

my_name.lower()

# %%
my_name

# %%
my_name.upper()

# %% [markdown]
# ## Removing Whitespaces from a String

# %%
# .rstrip(), .lstrip(), and .strip()

# %%
name_right = "Karthik P. N.   "
name_left = "   Karthik P. N."
name = "   Karthik P. N.   "

# %%
name_right.rstrip()

# %%
name_left.lstrip()

# %%
name.strip()

# %% [markdown]
# ## Determine if a String Starts or Ends With a Particular String

# %%
course_name = "Programming for AI"
course_name.startswith("Pro")

# %%
course_name.startswith("pro")

# %%
course_name.endswith("I")

# %% [markdown]
# ## Strings and Numbers

# %%
num = "2"
num + num

# %%
num = "12"
num * 3

# %%
3 * num

# %%
"12" * "3"

# %%
num = input("Enter a number to be doubled: ")
num = int(num)
num * 2

# %%
num_pancakes = 10
"I am going to eat " + str(num_pancakes) + " pancakes."

# %% [markdown]
# ## Streamlining Print Statements -- f strings

# %%
f"I am going to eat {num_pancakes} pancakes"

# %%
n = 3
m = 4
f"{n} times {m} is {n * m}"

new_f_string = f"{n} times {m} is {n * m}"
type(new_f_string)
print(new_f_string)
print(type(new_f_string))

# %% [markdown]
# ## Finding a string within a string

# %%
phrase = "the surprise is in here somewhere"
phrase.find("surprise")

# %%
phrase = "the surprise is in here somewhere"
phrase.find("qwertyuiop")

# %%
"My number is 555-555-5555".find("5")

# %%
# find only returns the first occurrence of a string within another. What if we want all occurrences?
# Unfortunately, there is no built-in function which can do this.
# But we will learn another technique of getting all occurrences using "regular expressions" (future lecture).

# %% [markdown]
# ## Replacing One String with Another

# %%
my_story = "I'm telling you the truth; nothing but the truth!"
my_story.replace("the truth", "lies")
